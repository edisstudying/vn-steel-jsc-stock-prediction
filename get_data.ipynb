# %%
#cd vnquant
#python setup.py install
from vnquant.DataLoader import DataLoader
import pandas as pd

# %%
hpg = DataLoader(symbols="HPG",
           start="2010-01-01",
           end="2022-01-01",
           data_source="cafe").download()
data = hpg.to_csv(r'C:\Users\Chi\Desktop\satellite\C\vn_stock_prediction\data\HPG.csv')
hpg.head()
# Out:
# c:\Users\Chi\.conda\envs\stenv\lib\site-packages\vnquant-0.0.2-py3.10.egg\vnquant\DataLoader.py:209: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data.change_perc.apply(utils.split_change_col).str
# 2022-08-30 16:18:57,634 : INFO : data HPG from 2010-01-01 to 2022-01-01 have already cloned!
# Attributes  high   low  open close adjust   volume
# Symbols      HPG   HPG   HPG   HPG    HPG      HPG
# date
# 2010-01-04  61.0  60.0  60.0  61.0   1.97   653120
# 2010-01-05  64.0  61.0  64.0  64.0   2.06  1203080
# 2010-01-06  66.0  63.0  63.5  66.0   2.13  1771660
# 2010-01-07  69.0  66.0  67.0  68.0   2.19  1535800
# 2010-01-08  69.5  65.0  69.5  65.0   2.10   909010

# %%
vis = DataLoader(symbols="VIS",
           start="2010-01-01",
           end="2022-01-01",
           data_source="cafe").download()
data = vis.to_csv(r'C:\Users\Chi\Desktop\satellite\C\vn_stock_prediction\data\VIS.csv')
vis.head()
# Out:
# c:\Users\Chi\.conda\envs\stenv\lib\site-packages\vnquant-0.0.2-py3.10.egg\vnquant\DataLoader.py:209: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data.change_perc.apply(utils.split_change_col).str
# 2022-08-30 16:20:27,767 : INFO : data VIS from 2010-01-01 to 2022-01-01 have already cloned!
# Attributes   high   low  open close adjust  volume
# Symbols       VIS   VIS   VIS   VIS    VIS     VIS
# date
# 2010-01-04   86.5  86.5  86.5  86.5  35.45  218640
# 2010-01-05   90.5  90.5  90.5  90.5  37.09   92400
# 2010-01-06   95.0  92.0  94.0  95.0  38.93  300910
# 2010-01-07   99.5  98.5  99.5  99.0  40.57  690830
# 2010-01-08  100.0  94.5  99.5  94.5  38.73  527970

# %%
dtl = DataLoader(symbols="DTL",
           start="2010-01-01",
           end="2022-01-01",
           data_source="cafe").download()
data = dtl.to_csv(r'C:\Users\Chi\Desktop\satellite\C\vn_stock_prediction\data\DTL.csv')
dtl.head()
# Out:
# c:\Users\Chi\.conda\envs\stenv\lib\site-packages\vnquant-0.0.2-py3.10.egg\vnquant\DataLoader.py:209: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data.change_perc.apply(utils.split_change_col).str
# 2022-08-30 16:19:53,647 : INFO : data DTL from 2010-01-01 to 2022-01-01 have already cloned!
# Attributes  high   low  open close adjust  volume
# Symbols      DTL   DTL   DTL   DTL    DTL     DTL
# date
# 2010-06-04  32.9  31.0  32.9  31.1  17.49  958770
# 2010-06-07  30.9  30.0  30.1  30.1  16.93  174100
# 2010-06-08  31.6  30.0  31.6  30.6  17.21  296830
# 2010-06-09  30.7  30.0  30.6  30.1  16.93  270660
# 2010-06-10  30.0  28.7  29.4  29.0  16.31  171510

# %%
hsg = DataLoader(symbols="HSG",
           start="2010-01-01",
           end="2022-01-01",
           data_source="cafe").download()
data = hsg.to_csv(r'C:\Users\Chi\Desktop\satellite\C\vn_stock_prediction\data\HSG.csv')
hsg.head()
# Out:
# c:\Users\Chi\.conda\envs\stenv\lib\site-packages\vnquant-0.0.2-py3.10.egg\vnquant\DataLoader.py:209: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data.change_perc.apply(utils.split_change_col).str
# 2022-08-30 16:21:02,263 : INFO : data HSG from 2010-01-01 to 2022-01-01 have already cloned!
# Attributes  high   low  open close adjust   volume
# Symbols      HSG   HSG   HSG   HSG    HSG      HSG
# date
# 2010-01-04  52.0  50.5  51.0  52.0   5.02  1420060
# 2010-01-05  54.5  52.5  54.5  53.0   5.12   850480
# 2010-01-06  55.5  53.0  53.0  55.5   5.36  1497290
# 2010-01-07  57.5  55.0  57.0  55.0   5.31   968590
# 2010-01-08  57.0  52.5  56.0  52.5   5.07   826260
